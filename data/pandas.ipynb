# %%
! pip install pandas

# %%
import pandas as pd
import json
import csv

data = '''
[
    {
        "itemId": 1,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 16.11,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 2,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 90.78,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 3,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 28.17,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 4,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 32.55,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 5,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 53.54,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 6,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 97.09,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 7,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 82.04,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 8,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 81.11,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 9,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 70.97,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 10,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 96.69,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 11,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 44.16,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 12,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 93.03,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 13,
        "name": "Hat",
        "description": "Made from premium materials.",
        "price": 67.95,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 14,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 69.77,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 15,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 55.32,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 16,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 12.5,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 17,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 17.99,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 18,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 52.77,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 19,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 55.25,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 20,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 44.01,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 21,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 67.51,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 22,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 20.19,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 23,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 45.52,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 24,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 97.75,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 25,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 36.2,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 26,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 42.4,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 27,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 66.46,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 28,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 89.53,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 29,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 72.71,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 30,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 56.02,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 31,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 42.89,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 32,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 41.33,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 33,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 41.23,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 34,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 84.04,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 35,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 56.05,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 36,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 80.33,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 37,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 34.7,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 38,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 31.43,
        "color": "Green",
        "category": "Accessories",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 39,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 27.04,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 6
    },
    {
        "itemId": 40,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 92.87,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 41,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 35.65,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 42,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 21.55,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 43,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 25.4,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 44,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 22.57,
        "color": "Red",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 45,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 32.18,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 46,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 17.58,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 47,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 87.42,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 48,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 61.16,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 49,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 36.91,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 8
    },
    {
        "itemId": 50,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 23.81,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 51,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 97.58,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 52,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 66.55,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 53,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 41.81,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 54,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 28.31,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 55,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 94.3,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 56,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 49.41,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 57,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 28.24,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 58,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 74.98,
        "color": "Red",
        "category": "Accessories",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 59,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 47.2,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 8
    },
    {
        "itemId": 60,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 63.11,
        "color": "Green",
        "category": "Accessories",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 61,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 46.18,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 62,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 25.65,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 63,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 98.66,
        "color": "Green",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 64,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 22.01,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 65,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 10.63,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 66,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 92.48,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 67,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 99.79,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 68,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 21.74,
        "color": "Red",
        "category": "Accessories",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 69,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 70.96,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 70,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 61.13,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 71,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 63.82,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 72,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 21.4,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 73,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 26.85,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 74,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 95.45,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 75,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 62.23,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 76,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 25.79,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 77,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 92.76,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 78,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 90.95,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 79,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 88.26,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 80,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 90.63,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 2
    },
    {
        "itemId": 81,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 36.11,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 82,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 72.72,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 83,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 73.52,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 7
    },
    {
        "itemId": 84,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 35.46,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 85,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 66.87,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 86,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 25.08,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 87,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 52.96,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 88,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 12.98,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 89,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 64.23,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 90,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 83.62,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 91,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 82.86,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 92,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 57.06,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 93,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 26.68,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 94,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 41.63,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 95,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 29.04,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 96,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 65.51,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 6
    },
    {
        "itemId": 97,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 81.83,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 98,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 24.85,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 99,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 46.13,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 100,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 75.86,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 101,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 69.9,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 102,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 78.74,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 103,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 99.18,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 104,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 11.6,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 7
    },
    {
        "itemId": 105,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 40.2,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 106,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 45.33,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 107,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 48.8,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 108,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 21.99,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 6
    },
    {
        "itemId": 109,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 62.31,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 110,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 72.2,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 111,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 22.03,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 112,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 54.34,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 113,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 23.93,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 114,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 94.41,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 115,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 52.57,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 116,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 76.87,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 117,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 29.03,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 118,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 93.56,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 119,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 83.02,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 120,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 13.19,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 121,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 83.42,
        "color": "Green",
        "category": "Accessories",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 122,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 20.82,
        "color": "Green",
        "category": "Accessories",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 123,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 95.47,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 124,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 89.04,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 125,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 31.67,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 126,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 85.46,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 127,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 19.1,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 128,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 12.38,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 129,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 86.52,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 130,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 96.85,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 131,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 15.75,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 132,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 45.86,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 133,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 54.59,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 134,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 90.11,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 135,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 22.94,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 136,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 86.02,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 137,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 79.66,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 138,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 22.54,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 139,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 92.47,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 140,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 65.99,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 141,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 71.33,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 142,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 82.04,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 143,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 46.91,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 144,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 32.85,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 145,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 36.19,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 146,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 58.21,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 147,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 21.57,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 148,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 44.2,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 149,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 22.89,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 150,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 12.1,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 151,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 90.34,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 4
    },
    {
        "itemId": 152,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 30.72,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 153,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 32.91,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 154,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 34.75,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 155,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 33.78,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 156,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 60.25,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 157,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 32.18,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 158,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 69.28,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 159,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 98.19,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 160,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 67.79,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 161,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 16.83,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 162,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 76.26,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 163,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 55.14,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 164,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 23.05,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 165,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 52.72,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 166,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 41.1,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 7
    },
    {
        "itemId": 167,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 52.93,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 168,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 45.8,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 169,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 43.68,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 170,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 52.58,
        "color": "Red",
        "category": "Accessories",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 171,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 33.85,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 172,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 66.52,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 173,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 56.38,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 174,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 59.15,
        "color": "Red",
        "category": "Accessories",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 175,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 78.72,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 176,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 47.73,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 177,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 65.89,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 178,
        "name": "Belt",
        "description": "Essential for your wardrobe.",
        "price": 35.88,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 179,
        "name": "Belt",
        "description": "Essential for your wardrobe.",
        "price": 55.16,
        "color": "Red",
        "category": "Accessories",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 180,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 56.97,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 181,
        "name": "Hat",
        "description": "Made from premium materials.",
        "price": 84.24,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 182,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 47.3,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 183,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 96.0,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 184,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 92.38,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 185,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 81.06,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 186,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 39.26,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 187,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 17.14,
        "color": "Red",
        "category": "Accessories",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 188,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 96.53,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 189,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 99.69,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 190,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 94.06,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 191,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 54.49,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 4
    },
    {
        "itemId": 192,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 33.14,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 193,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 15.96,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 194,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 54.58,
        "color": "Green",
        "category": "Accessories",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 195,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 18.8,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 196,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 30.02,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 197,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 20.35,
        "color": "Green",
        "category": "Accessories",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 198,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 86.23,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 199,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 27.88,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 200,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 26.03,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 201,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 27.37,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 202,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 96.3,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 203,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 51.81,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 204,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 55.83,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 205,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 49.59,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 206,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 68.36,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 207,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 40.59,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 208,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 12.77,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 209,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 92.6,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 210,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 43.27,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 211,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 70.77,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 8
    },
    {
        "itemId": 212,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 24.21,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 213,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 72.24,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 214,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 91.43,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 215,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 58.8,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 216,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 79.9,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 217,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 78.24,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 218,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 12.14,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 219,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 74.27,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 220,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 18.85,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 221,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 97.38,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 222,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 62.89,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 223,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 40.35,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 224,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 41.66,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 225,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 39.86,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 226,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 67.51,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 227,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 48.9,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 228,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 78.5,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 229,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 97.98,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 230,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 70.11,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 231,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 81.17,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 232,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 19.17,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 233,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 43.08,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 234,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 29.53,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 235,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 88.06,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 236,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 12.75,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 237,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 99.07,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 238,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 41.58,
        "color": "Green",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 239,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 44.56,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 240,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 24.99,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 241,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 44.12,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 242,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 93.87,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 243,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 66.56,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 244,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 51.78,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 245,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 98.3,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 246,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 19.7,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 247,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 79.21,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 248,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 70.61,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 249,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 79.82,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 250,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 33.22,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 251,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 92.26,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 252,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 86.34,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 253,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 35.28,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 254,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 53.9,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 255,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 76.31,
        "color": "Red",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 256,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 50.31,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 257,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 36.56,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 258,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 28.05,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 259,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 87.02,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 260,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 79.91,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 261,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 30.97,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 262,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 71.97,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 263,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 93.76,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 264,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 72.4,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 265,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 22.14,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 266,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 28.03,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 267,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 85.37,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 268,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 88.54,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 269,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 17.7,
        "color": "Green",
        "category": "Accessories",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 270,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 87.9,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 271,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 96.27,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 272,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 68.48,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 273,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 95.61,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 274,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 87.66,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 275,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 88.43,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 276,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 65.04,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 277,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 17.43,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 278,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 55.49,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 279,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 27.98,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 280,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 23.64,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 281,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 94.94,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 282,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 72.92,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 283,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 75.39,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 284,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 40.91,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 285,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 97.22,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 286,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 13.83,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 287,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 71.77,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 288,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 99.8,
        "color": "Green",
        "category": "Accessories",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 289,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 13.08,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 290,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 52.84,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 291,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 51.17,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 292,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 55.1,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 293,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 85.18,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 294,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 44.55,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 295,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 48.08,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 296,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 71.99,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 297,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 49.32,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 298,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 36.61,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 299,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 71.07,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 300,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 45.24,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 301,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 28.17,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 302,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 65.02,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 303,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 38.71,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 304,
        "name": "Blouse",
        "description": "Affordable and durable.",
        "price": 10.06,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 305,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 21.5,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 8
    },
    {
        "itemId": 306,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 70.1,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 307,
        "name": "Hat",
        "description": "Made from premium materials.",
        "price": 24.88,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 308,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 62.06,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 309,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 10.11,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 310,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 35.49,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 311,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 24.99,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 312,
        "name": "Hat",
        "description": "Made from premium materials.",
        "price": 38.86,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 7
    },
    {
        "itemId": 313,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 35.93,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 314,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 88.7,
        "color": "Green",
        "category": "Accessories",
        "popularity": 5,
        "durability": 6
    },
    {
        "itemId": 315,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 16.23,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 316,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 35.5,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 317,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 47.51,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 318,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 15.84,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 319,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 97.0,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 320,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 23.54,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 321,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 89.8,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 322,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 75.21,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 323,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 39.63,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 324,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 45.2,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 325,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 62.73,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 326,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 43.51,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 327,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 57.76,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 328,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 39.27,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 329,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 34.1,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 330,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 13.04,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 331,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 27.14,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 332,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 26.08,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 333,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 29.93,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 334,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 16.74,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 335,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 65.14,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 336,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 23.03,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 337,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 45.43,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 338,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 99.34,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 339,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 13.23,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 340,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 60.2,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 341,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 19.8,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 342,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 58.81,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 343,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 52.97,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 344,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 44.41,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 345,
        "name": "Hoodie",
        "description": "Made from premium materials.",
        "price": 55.6,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 346,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 52.42,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 347,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 92.42,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 348,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 88.41,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 349,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 97.72,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 350,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 26.07,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 351,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 34.4,
        "color": "Red",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 352,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 95.16,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 353,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 57.06,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 354,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 48.98,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 355,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 15.86,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 356,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 66.39,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 357,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 90.28,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 358,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 98.05,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 359,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 10.65,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 360,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 51.51,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 361,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 88.4,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 362,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 24.95,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 363,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 72.42,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 364,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 47.79,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 365,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 17.78,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 366,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 13.6,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 367,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 45.54,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 368,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 36.84,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 369,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 14.14,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 370,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 72.58,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 371,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 94.09,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 372,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 88.39,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 373,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 42.63,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 374,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 34.47,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 375,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 18.46,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 376,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 47.79,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 377,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 80.04,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 378,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 25.39,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 379,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 48.43,
        "color": "Green",
        "category": "Accessories",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 380,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 53.96,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 381,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 30.39,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 382,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 97.45,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 383,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 98.92,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 384,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 44.68,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 385,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 37.07,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 386,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 33.9,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 387,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 38.06,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 388,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 76.0,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 389,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 17.84,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 390,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 98.06,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 391,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 66.03,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 392,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 23.16,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 393,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 36.16,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 394,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 83.31,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 395,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 89.66,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 396,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 32.03,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 397,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 26.79,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 398,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 52.17,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 399,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 48.84,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 400,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 35.58,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 401,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 53.39,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 402,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 11.59,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 403,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 62.01,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 404,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 63.37,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 405,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 46.17,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 406,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 87.96,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 407,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 92.07,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 408,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 91.11,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 409,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 81.14,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 410,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 80.47,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 411,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 86.63,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 412,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 39.03,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 413,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 44.84,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 414,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 54.95,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 415,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 68.78,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 416,
        "name": "Hoodie",
        "description": "Affordable and durable.",
        "price": 37.1,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 417,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 13.33,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 418,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 46.6,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 419,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 36.05,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 420,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 12.97,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 421,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 63.16,
        "color": "Green",
        "category": "Accessories",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 422,
        "name": "Blouse",
        "description": "Affordable and durable.",
        "price": 91.3,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 423,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 50.69,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 424,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 61.48,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 425,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 77.42,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 426,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 79.42,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 427,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 55.03,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 428,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 73.2,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 429,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 11.52,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 430,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 76.96,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 431,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 85.16,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 432,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 65.72,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 433,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 41.53,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 434,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 42.24,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 435,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 87.87,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 436,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 10.27,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 437,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 11.83,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 438,
        "name": "Hat",
        "description": "Affordable and durable.",
        "price": 97.02,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 439,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 57.96,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 440,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 55.23,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 441,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 57.3,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 442,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 21.04,
        "color": "Green",
        "category": "Accessories",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 443,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 10.03,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 444,
        "name": "Hoodie",
        "description": "Made from premium materials.",
        "price": 37.73,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 445,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 36.75,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 446,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 12.28,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 447,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 25.31,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 448,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 18.36,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 449,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 67.44,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 450,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 48.66,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 451,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 79.51,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 452,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 74.48,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 453,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 55.55,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 454,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 27.37,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 455,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 12.89,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 456,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 73.59,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 457,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 37.67,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 458,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 53.67,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 459,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 59.29,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 460,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 94.36,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 461,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 11.5,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 462,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 26.67,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 463,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 70.62,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 464,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 66.83,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 465,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 73.07,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 466,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 17.56,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 467,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 59.34,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 468,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 99.19,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 469,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 52.72,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 470,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 24.24,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 471,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 26.07,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 472,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 34.25,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 473,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 86.29,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 474,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 11.83,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 475,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 90.41,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 476,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 86.96,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 477,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 61.98,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 478,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 45.23,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 479,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 27.93,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 480,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 97.49,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 481,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 85.31,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 482,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 21.16,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 483,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 16.11,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 484,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 67.29,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 485,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 41.11,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 486,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 70.77,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 487,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 69.36,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 488,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 89.13,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 489,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 81.48,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 490,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 62.5,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 491,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 79.96,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 492,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 62.47,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 493,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 42.63,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 494,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 77.68,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 495,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 27.9,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 496,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 11.99,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 497,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 45.22,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 498,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 32.72,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 7
    },
    {
        "itemId": 499,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 82.96,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 500,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 71.54,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 501,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 53.3,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 502,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 75.77,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 503,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 83.27,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 504,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 12.5,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 505,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 41.27,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 506,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 18.66,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 507,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 87.14,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 508,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 44.75,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 509,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 68.52,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 510,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 93.44,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 511,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 76.01,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 512,
        "name": "Blouse",
        "description": "Perfect for any occasion.",
        "price": 84.12,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 513,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 46.74,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 514,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 40.73,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 515,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 81.82,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 516,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 34.22,
        "color": "Red",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 517,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 60.52,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 518,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 68.88,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 519,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 29.8,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 520,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 80.13,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 521,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 99.8,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 522,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 23.0,
        "color": "Red",
        "category": "Accessories",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 523,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 20.3,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 524,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 72.38,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 525,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 85.54,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 526,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 94.87,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 527,
        "name": "Hoodie",
        "description": "Affordable and durable.",
        "price": 45.4,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 528,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 73.58,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 529,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 43.65,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 530,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 22.5,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 531,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 88.71,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 532,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 92.04,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 533,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 70.11,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 534,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 95.65,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 535,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 88.29,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 536,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 90.24,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 537,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 97.27,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 8
    },
    {
        "itemId": 538,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 73.62,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 539,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 41.48,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 540,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 75.15,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 541,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 75.66,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 542,
        "name": "Jeans",
        "description": "A great addition to your collection.",
        "price": 30.09,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 543,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 39.25,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 544,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 88.19,
        "color": "Red",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 545,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 13.39,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 546,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 99.11,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 547,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 86.47,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 548,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 47.86,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 549,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 49.07,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 550,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 92.76,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 551,
        "name": "Handbag",
        "description": "Made from premium materials.",
        "price": 33.14,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 552,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 63.94,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 553,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 35.42,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 554,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 58.64,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 555,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 55.18,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 556,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 43.01,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 557,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 96.15,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 558,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 71.96,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 559,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 24.71,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 560,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 51.66,
        "color": "Green",
        "category": "Accessories",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 561,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 15.31,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 562,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 17.33,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 563,
        "name": "Belt",
        "description": "Essential for your wardrobe.",
        "price": 49.72,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 564,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 49.42,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 565,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 55.58,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 566,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 58.07,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 567,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 24.03,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 568,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 91.02,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 569,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 51.09,
        "color": "Green",
        "category": "Accessories",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 570,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 63.48,
        "color": "Green",
        "category": "Accessories",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 571,
        "name": "Hat",
        "description": "Affordable and durable.",
        "price": 80.3,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 572,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 62.57,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 573,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 79.6,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 574,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 68.54,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 575,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 83.7,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 576,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 90.59,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 577,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 15.14,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 578,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 30.26,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 579,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 89.66,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 580,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 94.4,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 581,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 28.39,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 582,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 79.58,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 7
    },
    {
        "itemId": 583,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 75.01,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 584,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 82.4,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 585,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 24.48,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 586,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 46.88,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 587,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 37.93,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 588,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 13.21,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 589,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 12.0,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 590,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 73.73,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 591,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 95.49,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 592,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 71.02,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 593,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 12.22,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 594,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 36.88,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 595,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 29.33,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 596,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 64.03,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 597,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 37.4,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 598,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 44.22,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 599,
        "name": "Hat",
        "description": "Affordable and durable.",
        "price": 86.96,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 600,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 68.62,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 601,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 52.32,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 602,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 78.87,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 603,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 49.57,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 604,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 45.18,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 605,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 47.2,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 606,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 39.74,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 607,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 76.96,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 608,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 29.87,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 609,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 79.85,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 610,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 65.4,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 611,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 15.63,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 612,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 79.98,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 613,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 22.62,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 614,
        "name": "Belt",
        "description": "Made from premium materials.",
        "price": 20.82,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 615,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 12.38,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 8
    },
    {
        "itemId": 616,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 68.59,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 617,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 73.02,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 618,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 99.35,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 619,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 32.54,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 620,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 30.27,
        "color": "Red",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 621,
        "name": "Hoodie",
        "description": "Affordable and durable.",
        "price": 96.89,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 622,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 84.46,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 623,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 98.7,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 624,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 42.48,
        "color": "Red",
        "category": "Accessories",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 625,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 65.32,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 626,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 16.91,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 627,
        "name": "Jeans",
        "description": "Made from premium materials.",
        "price": 73.73,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 628,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 65.3,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 629,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 64.45,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 630,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 83.23,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 631,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 73.87,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 632,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 92.34,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 633,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 48.86,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 634,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 39.72,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 635,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 10.07,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 636,
        "name": "Hoodie",
        "description": "Affordable and durable.",
        "price": 98.08,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 637,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 94.64,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 638,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 30.2,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 639,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 61.77,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 640,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 22.99,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 641,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 23.96,
        "color": "Green",
        "category": "Accessories",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 642,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 91.63,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 643,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 17.53,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 644,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 33.35,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 645,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 11.47,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 646,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 25.35,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 647,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 94.35,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 648,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 30.43,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 649,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 60.41,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 650,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 15.49,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 651,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 62.2,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 652,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 21.64,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 653,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 58.74,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 654,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 49.56,
        "color": "Red",
        "category": "Accessories",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 655,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 56.94,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 3
    },
    {
        "itemId": 656,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 11.34,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 8
    },
    {
        "itemId": 657,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 30.21,
        "color": "Green",
        "category": "Accessories",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 658,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 32.37,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 659,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 26.06,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 660,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 36.81,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 661,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 62.15,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 662,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 60.46,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 663,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 95.77,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 664,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 95.05,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 665,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 38.0,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 666,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 37.07,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 667,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 94.46,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 668,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 50.52,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 669,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 79.8,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 670,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 81.71,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 671,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 59.93,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 672,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 91.12,
        "color": "Green",
        "category": "Accessories",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 673,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 21.63,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 674,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 25.94,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 675,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 41.34,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 8
    },
    {
        "itemId": 676,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 73.5,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 677,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 90.36,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 678,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 82.69,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 679,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 56.55,
        "color": "Red",
        "category": "Accessories",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 680,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 65.86,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 681,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 58.24,
        "color": "Green",
        "category": "Accessories",
        "popularity": 6,
        "durability": 1
    },
    {
        "itemId": 682,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 86.87,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 683,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 37.27,
        "color": "Green",
        "category": "Accessories",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 684,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 68.43,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 685,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 45.55,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 686,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 25.32,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 687,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 58.3,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 688,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 46.93,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 689,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 34.32,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 690,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 30.94,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 691,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 38.76,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 692,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 79.32,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 5
    },
    {
        "itemId": 693,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 85.07,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 694,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 15.27,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 695,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 16.77,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 696,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 11.36,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 697,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 55.52,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 698,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 71.96,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 699,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 31.06,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 700,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 20.61,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 701,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 11.17,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 702,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 91.1,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 703,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 21.34,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 704,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 26.24,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 705,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 21.68,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 706,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 18.15,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 707,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 45.0,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 708,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 57.14,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 709,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 10.72,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 710,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 89.6,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 711,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 92.6,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 712,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 63.05,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 713,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 17.93,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 714,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 55.98,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 715,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 52.34,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 716,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 54.65,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 717,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 48.58,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 718,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 34.69,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 719,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 15.61,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 7
    },
    {
        "itemId": 720,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 95.82,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 721,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 67.35,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 722,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 96.26,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 723,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 73.41,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 724,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 21.64,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 725,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 66.01,
        "color": "Red",
        "category": "Accessories",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 726,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 59.67,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 727,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 46.33,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 728,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 32.63,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 729,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 46.13,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 730,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 81.17,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 731,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 98.05,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 732,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 65.94,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 8
    },
    {
        "itemId": 733,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 88.13,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 734,
        "name": "Jeans",
        "description": "Perfect for any occasion.",
        "price": 19.49,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 735,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 83.2,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 736,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 13.98,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 737,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 86.03,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 738,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 52.49,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 739,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 29.75,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 740,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 20.38,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 741,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 82.16,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 742,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 90.12,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 10,
        "durability": 2
    },
    {
        "itemId": 743,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 56.06,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 744,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 53.16,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 745,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 28.93,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 746,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 88.89,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 747,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 87.58,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 748,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 61.76,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 749,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 37.75,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 750,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 33.44,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 9
    },
    {
        "itemId": 751,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 70.37,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 752,
        "name": "Jeans",
        "description": "Trendy and fashionable.",
        "price": 92.66,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 753,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 95.57,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 754,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 40.1,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 755,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 23.86,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 4
    },
    {
        "itemId": 756,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 54.76,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 757,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 81.7,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 758,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 50.74,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 759,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 77.37,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 760,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 74.82,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 761,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 43.09,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 762,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 80.07,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 8
    },
    {
        "itemId": 763,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 71.33,
        "color": "Red",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 764,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 16.35,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 765,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 70.83,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 766,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 66.76,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 767,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 82.74,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 768,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 24.87,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 769,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 53.01,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 5,
        "durability": 6
    },
    {
        "itemId": 770,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 23.89,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 4
    },
    {
        "itemId": 771,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 43.63,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 772,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 59.63,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 773,
        "name": "Belt",
        "description": "Affordable and durable.",
        "price": 41.58,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 774,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 56.09,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 775,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 17.4,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 776,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 52.33,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 777,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 77.77,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 778,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 83.96,
        "color": "Red",
        "category": "Accessories",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 779,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 63.71,
        "color": "Red",
        "category": "Accessories",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 780,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 90.42,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 781,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 86.86,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 782,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 68.19,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 783,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 42.38,
        "color": "Green",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 784,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 18.67,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 3,
        "durability": 10
    },
    {
        "itemId": 785,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 15.67,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 786,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 72.15,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 787,
        "name": "Blouse",
        "description": "Affordable and durable.",
        "price": 49.83,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 788,
        "name": "T-Shirt",
        "description": "High quality and durable.",
        "price": 54.41,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 10
    },
    {
        "itemId": 789,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 13.9,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 790,
        "name": "Blouse",
        "description": "Versatile and practical.",
        "price": 56.78,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 791,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 78.59,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 792,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 52.86,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 793,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 25.38,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 794,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 73.0,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 795,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 75.8,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 796,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 49.2,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 10
    },
    {
        "itemId": 797,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 46.6,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 798,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 34.91,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 799,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 96.2,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 800,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 61.41,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 1
    },
    {
        "itemId": 801,
        "name": "Sunglasses",
        "description": "Made from premium materials.",
        "price": 33.77,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 802,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 21.98,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 803,
        "name": "Belt",
        "description": "High quality and durable.",
        "price": 58.48,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 804,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 36.96,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 2
    },
    {
        "itemId": 805,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 67.87,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 806,
        "name": "Handbag",
        "description": "Versatile and practical.",
        "price": 15.29,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 807,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 19.65,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 808,
        "name": "Shoes",
        "description": "Trendy and fashionable.",
        "price": 71.04,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 809,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 28.17,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 7
    },
    {
        "itemId": 810,
        "name": "Dress",
        "description": "Affordable and durable.",
        "price": 71.33,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 811,
        "name": "Blouse",
        "description": "High quality and durable.",
        "price": 10.08,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 812,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 65.05,
        "color": "Green",
        "category": "Accessories",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 813,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 29.64,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 814,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 59.29,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 815,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 43.17,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 816,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 84.29,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 817,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 94.8,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 818,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 57.27,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 819,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 14.19,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 820,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 48.4,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 821,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 78.42,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 822,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 97.09,
        "color": "Red",
        "category": "Accessories",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 823,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 50.24,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 824,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 45.72,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 825,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 32.13,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 826,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 52.62,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 827,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 22.24,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 828,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 56.85,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 829,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 44.62,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 830,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 13.35,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 831,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 98.52,
        "color": "Green",
        "category": "Accessories",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 832,
        "name": "Dress",
        "description": "Made from premium materials.",
        "price": 83.58,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 1
    },
    {
        "itemId": 833,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 83.02,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 834,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 32.87,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 2
    },
    {
        "itemId": 835,
        "name": "Hoodie",
        "description": "Elegant and chic.",
        "price": 99.41,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 836,
        "name": "Belt",
        "description": "Perfect for any occasion.",
        "price": 85.94,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 837,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 63.67,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 838,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 62.86,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 6
    },
    {
        "itemId": 839,
        "name": "Shoes",
        "description": "Made from premium materials.",
        "price": 32.87,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 840,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 53.07,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 8
    },
    {
        "itemId": 841,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 18.91,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 842,
        "name": "Blouse",
        "description": "Essential for your wardrobe.",
        "price": 19.38,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 843,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 62.55,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 844,
        "name": "Blouse",
        "description": "A comfortable and stylish piece.",
        "price": 62.91,
        "color": "Red",
        "category": "Accessories",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 845,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 38.63,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 846,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 55.27,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 8
    },
    {
        "itemId": 847,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 39.68,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 848,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 63.37,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 849,
        "name": "Hoodie",
        "description": "Trendy and fashionable.",
        "price": 66.87,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 850,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 31.91,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 851,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 65.65,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 852,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 26.0,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 853,
        "name": "Belt",
        "description": "Essential for your wardrobe.",
        "price": 68.64,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 854,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 18.98,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 855,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 10.64,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 856,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 40.19,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 2,
        "durability": 6
    },
    {
        "itemId": 857,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 12.69,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 858,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 26.63,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 6
    },
    {
        "itemId": 859,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 22.59,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 860,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 91.53,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 861,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 36.38,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 862,
        "name": "Blouse",
        "description": "Affordable and durable.",
        "price": 25.01,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 9
    },
    {
        "itemId": 863,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 65.51,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 7,
        "durability": 3
    },
    {
        "itemId": 864,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 48.69,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 865,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 99.3,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 866,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 54.25,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 867,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 71.86,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 868,
        "name": "Handbag",
        "description": "Essential for your wardrobe.",
        "price": 11.55,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 869,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 65.21,
        "color": "Red",
        "category": "Accessories",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 870,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 21.92,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 4
    },
    {
        "itemId": 871,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 77.42,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 872,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 66.01,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 873,
        "name": "Jeans",
        "description": "Elegant and chic.",
        "price": 88.06,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 1
    },
    {
        "itemId": 874,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 25.34,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 4
    },
    {
        "itemId": 875,
        "name": "T-Shirt",
        "description": "Versatile and practical.",
        "price": 68.01,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 876,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 74.55,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 877,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 33.98,
        "color": "Red",
        "category": "Accessories",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 878,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 14.97,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 879,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 37.76,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 880,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 32.91,
        "color": "Red",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 881,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 65.08,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 882,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 46.7,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 4
    },
    {
        "itemId": 883,
        "name": "Sunglasses",
        "description": "Perfect for any occasion.",
        "price": 51.95,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 884,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 12.46,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 885,
        "name": "Belt",
        "description": "A great addition to your collection.",
        "price": 98.44,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 886,
        "name": "Hat",
        "description": "Trendy and fashionable.",
        "price": 30.26,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 887,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 20.63,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 7
    },
    {
        "itemId": 888,
        "name": "Shoes",
        "description": "A comfortable and stylish piece.",
        "price": 74.72,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 9
    },
    {
        "itemId": 889,
        "name": "Dress",
        "description": "High quality and durable.",
        "price": 32.75,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 1
    },
    {
        "itemId": 890,
        "name": "Sunglasses",
        "description": "Essential for your wardrobe.",
        "price": 92.34,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 891,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 54.25,
        "color": "Red",
        "category": "Accessories",
        "popularity": 4,
        "durability": 1
    },
    {
        "itemId": 892,
        "name": "T-Shirt",
        "description": "Perfect for any occasion.",
        "price": 93.35,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 893,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 90.94,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 894,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 33.76,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 895,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 76.47,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 896,
        "name": "Sunglasses",
        "description": "Elegant and chic.",
        "price": 12.42,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 897,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 19.12,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 2
    },
    {
        "itemId": 898,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 99.26,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 3
    },
    {
        "itemId": 899,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 22.76,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 7,
        "durability": 1
    },
    {
        "itemId": 900,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 90.98,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 10,
        "durability": 5
    },
    {
        "itemId": 901,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 84.97,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 4
    },
    {
        "itemId": 902,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 43.25,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 903,
        "name": "T-Shirt",
        "description": "A comfortable and stylish piece.",
        "price": 46.46,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 904,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 14.52,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 905,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 71.49,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 3,
        "durability": 4
    },
    {
        "itemId": 906,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 37.12,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 907,
        "name": "Shoes",
        "description": "Elegant and chic.",
        "price": 72.57,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 7
    },
    {
        "itemId": 908,
        "name": "Dress",
        "description": "Essential for your wardrobe.",
        "price": 56.51,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 909,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 30.11,
        "color": "Yellow",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 910,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 81.85,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 911,
        "name": "Dress",
        "description": "Trendy and fashionable.",
        "price": 87.51,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 912,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 16.43,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 6
    },
    {
        "itemId": 913,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 44.39,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 914,
        "name": "Dress",
        "description": "Perfect for any occasion.",
        "price": 88.98,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 1,
        "durability": 3
    },
    {
        "itemId": 915,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 94.57,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 8
    },
    {
        "itemId": 916,
        "name": "Hoodie",
        "description": "Versatile and practical.",
        "price": 95.84,
        "color": "Green",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 917,
        "name": "Handbag",
        "description": "Perfect for any occasion.",
        "price": 80.77,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 10
    },
    {
        "itemId": 918,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 82.79,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 4
    },
    {
        "itemId": 919,
        "name": "Shoes",
        "description": "High quality and durable.",
        "price": 51.78,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 920,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 42.92,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 921,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 46.5,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 922,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 73.61,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 9
    },
    {
        "itemId": 923,
        "name": "Shoes",
        "description": "A great addition to your collection.",
        "price": 36.6,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 3
    },
    {
        "itemId": 924,
        "name": "Blouse",
        "description": "Affordable and durable.",
        "price": 88.46,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 925,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 25.42,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 926,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 55.98,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 9
    },
    {
        "itemId": 927,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 98.0,
        "color": "Blue",
        "category": "Men's Clothing",
        "popularity": 4,
        "durability": 9
    },
    {
        "itemId": 928,
        "name": "Dress",
        "description": "A comfortable and stylish piece.",
        "price": 94.46,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 3
    },
    {
        "itemId": 929,
        "name": "Handbag",
        "description": "Affordable and durable.",
        "price": 84.03,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 3
    },
    {
        "itemId": 930,
        "name": "Belt",
        "description": "Versatile and practical.",
        "price": 54.4,
        "color": "Red",
        "category": "Accessories",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 931,
        "name": "Blouse",
        "description": "A great addition to your collection.",
        "price": 19.09,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 932,
        "name": "Hat",
        "description": "Made from premium materials.",
        "price": 15.11,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 933,
        "name": "Sunglasses",
        "description": "Trendy and fashionable.",
        "price": 61.89,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 9,
        "durability": 8
    },
    {
        "itemId": 934,
        "name": "Jeans",
        "description": "A great addition to your collection.",
        "price": 55.07,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 935,
        "name": "T-Shirt",
        "description": "Affordable and durable.",
        "price": 29.28,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 936,
        "name": "Jeans",
        "description": "Essential for your wardrobe.",
        "price": 54.39,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 937,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 81.72,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 5
    },
    {
        "itemId": 938,
        "name": "Jeans",
        "description": "A great addition to your collection.",
        "price": 12.22,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 1,
        "durability": 4
    },
    {
        "itemId": 939,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 35.07,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 940,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 63.53,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 10
    },
    {
        "itemId": 941,
        "name": "Blouse",
        "description": "Made from premium materials.",
        "price": 77.1,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 9
    },
    {
        "itemId": 942,
        "name": "Jeans",
        "description": "Versatile and practical.",
        "price": 13.51,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 943,
        "name": "Dress",
        "description": "Elegant and chic.",
        "price": 98.7,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 944,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 62.4,
        "color": "Yellow",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 3
    },
    {
        "itemId": 945,
        "name": "Sunglasses",
        "description": "Versatile and practical.",
        "price": 92.97,
        "color": "Blue",
        "category": "Accessories",
        "popularity": 1,
        "durability": 7
    },
    {
        "itemId": 946,
        "name": "Hoodie",
        "description": "A comfortable and stylish piece.",
        "price": 85.59,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 3,
        "durability": 5
    },
    {
        "itemId": 947,
        "name": "Jeans",
        "description": "Affordable and durable.",
        "price": 26.73,
        "color": "Indigo",
        "category": "Accessories",
        "popularity": 9,
        "durability": 2
    },
    {
        "itemId": 948,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 66.95,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 3,
        "durability": 4
    },
    {
        "itemId": 949,
        "name": "Handbag",
        "description": "Trendy and fashionable.",
        "price": 82.84,
        "color": "Red",
        "category": "Accessories",
        "popularity": 4,
        "durability": 5
    },
    {
        "itemId": 950,
        "name": "Belt",
        "description": "A comfortable and stylish piece.",
        "price": 41.88,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 7,
        "durability": 2
    },
    {
        "itemId": 951,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 28.46,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 8,
        "durability": 7
    },
    {
        "itemId": 952,
        "name": "Hoodie",
        "description": "Essential for your wardrobe.",
        "price": 35.63,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 953,
        "name": "Hat",
        "description": "Versatile and practical.",
        "price": 18.45,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 10
    },
    {
        "itemId": 954,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 95.55,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 1,
        "durability": 2
    },
    {
        "itemId": 955,
        "name": "Shoes",
        "description": "Affordable and durable.",
        "price": 12.42,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 956,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 16.73,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 7
    },
    {
        "itemId": 957,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 11.0,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 4
    },
    {
        "itemId": 958,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 71.99,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 2,
        "durability": 7
    },
    {
        "itemId": 959,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 90.35,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 2
    },
    {
        "itemId": 960,
        "name": "Blouse",
        "description": "Elegant and chic.",
        "price": 13.21,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 2
    },
    {
        "itemId": 961,
        "name": "Jeans",
        "description": "A comfortable and stylish piece.",
        "price": 19.38,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 2,
        "durability": 8
    },
    {
        "itemId": 962,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 72.34,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 1,
        "durability": 1
    },
    {
        "itemId": 963,
        "name": "Shoes",
        "description": "Versatile and practical.",
        "price": 27.32,
        "color": "Red",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 964,
        "name": "Hoodie",
        "description": "Perfect for any occasion.",
        "price": 76.39,
        "color": "Violet",
        "category": "Accessories",
        "popularity": 5,
        "durability": 7
    },
    {
        "itemId": 965,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 98.82,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 2
    },
    {
        "itemId": 966,
        "name": "Hat",
        "description": "A great addition to your collection.",
        "price": 65.0,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 3,
        "durability": 1
    },
    {
        "itemId": 967,
        "name": "Belt",
        "description": "Trendy and fashionable.",
        "price": 48.54,
        "color": "Red",
        "category": "Accessories",
        "popularity": 5,
        "durability": 5
    },
    {
        "itemId": 968,
        "name": "Belt",
        "description": "Essential for your wardrobe.",
        "price": 43.22,
        "color": "Indigo",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 6
    },
    {
        "itemId": 969,
        "name": "Jeans",
        "description": "High quality and durable.",
        "price": 79.82,
        "color": "Orange",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 3
    },
    {
        "itemId": 970,
        "name": "Hat",
        "description": "Perfect for any occasion.",
        "price": 77.86,
        "color": "Yellow",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 6
    },
    {
        "itemId": 971,
        "name": "Handbag",
        "description": "A great addition to your collection.",
        "price": 40.52,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 972,
        "name": "Belt",
        "description": "Elegant and chic.",
        "price": 30.96,
        "color": "Green",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 973,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 28.75,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 9
    },
    {
        "itemId": 974,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 24.83,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 7
    },
    {
        "itemId": 975,
        "name": "Handbag",
        "description": "High quality and durable.",
        "price": 23.27,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 9,
        "durability": 10
    },
    {
        "itemId": 976,
        "name": "Sunglasses",
        "description": "A comfortable and stylish piece.",
        "price": 53.74,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 7,
        "durability": 5
    },
    {
        "itemId": 977,
        "name": "Handbag",
        "description": "A comfortable and stylish piece.",
        "price": 63.74,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 6,
        "durability": 5
    },
    {
        "itemId": 978,
        "name": "Hoodie",
        "description": "A great addition to your collection.",
        "price": 31.08,
        "color": "Red",
        "category": "Accessories",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 979,
        "name": "Shoes",
        "description": "Perfect for any occasion.",
        "price": 60.04,
        "color": "Orange",
        "category": "Men's Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 980,
        "name": "Hat",
        "description": "A comfortable and stylish piece.",
        "price": 14.03,
        "color": "Green",
        "category": "Accessories",
        "popularity": 7,
        "durability": 10
    },
    {
        "itemId": 981,
        "name": "T-Shirt",
        "description": "Essential for your wardrobe.",
        "price": 92.86,
        "color": "Red",
        "category": "Unisex Clothing",
        "popularity": 5,
        "durability": 2
    },
    {
        "itemId": 982,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 44.04,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 6
    },
    {
        "itemId": 983,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 93.32,
        "color": "Green",
        "category": "Unisex Clothing",
        "popularity": 7,
        "durability": 7
    },
    {
        "itemId": 984,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 94.89,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 10,
        "durability": 10
    },
    {
        "itemId": 985,
        "name": "Hat",
        "description": "High quality and durable.",
        "price": 84.31,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 986,
        "name": "Hoodie",
        "description": "High quality and durable.",
        "price": 65.38,
        "color": "Violet",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 7
    },
    {
        "itemId": 987,
        "name": "Sunglasses",
        "description": "Affordable and durable.",
        "price": 24.03,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 6,
        "durability": 9
    },
    {
        "itemId": 988,
        "name": "Hat",
        "description": "Elegant and chic.",
        "price": 87.32,
        "color": "Orange",
        "category": "Women's Clothing",
        "popularity": 4,
        "durability": 10
    },
    {
        "itemId": 989,
        "name": "Blouse",
        "description": "Trendy and fashionable.",
        "price": 93.34,
        "color": "Blue",
        "category": "Women's Clothing",
        "popularity": 8,
        "durability": 2
    },
    {
        "itemId": 990,
        "name": "Sunglasses",
        "description": "High quality and durable.",
        "price": 67.76,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 5
    },
    {
        "itemId": 991,
        "name": "Dress",
        "description": "Versatile and practical.",
        "price": 19.82,
        "color": "Violet",
        "category": "Unisex Clothing",
        "popularity": 8,
        "durability": 3
    },
    {
        "itemId": 992,
        "name": "Hat",
        "description": "Essential for your wardrobe.",
        "price": 98.11,
        "color": "Violet",
        "category": "Men's Clothing",
        "popularity": 10,
        "durability": 8
    },
    {
        "itemId": 993,
        "name": "T-Shirt",
        "description": "A great addition to your collection.",
        "price": 53.86,
        "color": "Blue",
        "category": "Unisex Clothing",
        "popularity": 4,
        "durability": 6
    },
    {
        "itemId": 994,
        "name": "T-Shirt",
        "description": "Elegant and chic.",
        "price": 92.4,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 1,
        "durability": 6
    },
    {
        "itemId": 995,
        "name": "Shoes",
        "description": "Essential for your wardrobe.",
        "price": 44.9,
        "color": "Red",
        "category": "Accessories",
        "popularity": 9,
        "durability": 1
    },
    {
        "itemId": 996,
        "name": "T-Shirt",
        "description": "Made from premium materials.",
        "price": 98.56,
        "color": "Orange",
        "category": "Accessories",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 997,
        "name": "Handbag",
        "description": "Elegant and chic.",
        "price": 40.29,
        "color": "Indigo",
        "category": "Unisex Clothing",
        "popularity": 2,
        "durability": 9
    },
    {
        "itemId": 998,
        "name": "T-Shirt",
        "description": "Trendy and fashionable.",
        "price": 25.91,
        "color": "Red",
        "category": "Accessories",
        "popularity": 9,
        "durability": 5
    },
    {
        "itemId": 999,
        "name": "Dress",
        "description": "A great addition to your collection.",
        "price": 18.45,
        "color": "Indigo",
        "category": "Men's Clothing",
        "popularity": 6,
        "durability": 8
    },
    {
        "itemId": 1000,
        "name": "Sunglasses",
        "description": "A great addition to your collection.",
        "price": 46.15,
        "color": "Yellow",
        "category": "Accessories",
        "popularity": 9,
        "durability": 2
    }
]
'''


json_data =json.loads(data)

# %%
df = pd.DataFrame(json_data)

# %%
csv_file = 'output.csv'
df.to_csv(csv_file, index=False)
